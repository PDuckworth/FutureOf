# %% [markdown]
# # Querying the Task Dataset

# %% [markdown]
# ## Observational Data:

# %%
# encoding=utf8
import os
import numpy as np
import pandas as pd
import getpass
import pickle
import string
import matplotlib.pyplot as plt
# %matplotlib inline

# Point this at the ONET data: 
datasets = '/home/'+ getpass.getuser() +'/Datasets/ONET/'
# datasets = '/Users/Logan/Google Drive/Oxford/DPhil/projects/past/future_employment/data/'
print(datasets)
# Out:
# /home/scpd/Datasets/ONET/

# %%
occupations = pd.read_table(os.path.join(datasets, 'databases/db2016/Occupation Data.txt'), sep='\t')
occupations.rename(columns = {'Title':'Occupation title'}, inplace = True)
occupations.head()
# Out:
#   O*NET-SOC Code                     Occupation title  \
# 0     11-1011.00                     Chief Executives
# 1     11-1011.03        Chief Sustainability Officers
# 2     11-1021.00      General and Operations Managers
# 3     11-1031.00                          Legislators
# 4     11-2011.00  Advertising and Promotions Managers
#
#                                                                                                                                                                                                Description
# 0  Determine and formulate policies and provide overall direction of companies or private and public sector organizations within guidelines set up by a board of directors or similar governing body. P...
# 1                               Communicate and coordinate with management, shareholders, customers, and employees to address sustainability issues. Enact or oversee a corporate sustainability strategy.
# 2  Plan, direct, or coordinate the operations of public or private sector organizations. Duties and responsibilities include formulating policies, managing daily operations, and planning the use of m...
# 3                                                                 Develop, introduce or enact laws and statutes at the local, tribal, State, or Federal level. Includes only workers in elected positions.
# 4  Plan, direct, or coordinate advertising policies and programs or produce collateral materials, such as posters, contests, coupons, or give-aways, to create extra interest in the purchase of a prod...

# %%
tasks = pd.read_table(os.path.join(datasets, 'databases/db2016/Task Statements.txt'), sep='\t')

# tasks = tasks[['O*NET-SOC Code', 'Task ID', 'Task']]
reduced_tasks = tasks[tasks['O*NET-SOC Code'].isin(tasks['O*NET-SOC Code'].unique())]

# All tasks are unique to Occupation it seems
print(tasks.shape, tasks['O*NET-SOC Code'].unique().shape, reduced_tasks.shape)
tasks.head()
# Out:
# (19566, 7) (974,) (19566, 7)
#   O*NET-SOC Code  Task ID                                               Task  \
# 0     11-1011.00     8823  Direct or coordinate an organization's financi...
# 1     11-1011.00     8831  Appoint department heads or managers and assig...
# 2     11-1011.00     8825  Analyze operations to evaluate performance of ...
# 3     11-1011.00     8826  Direct, plan, or implement policies, objective...
# 4     11-1011.00     8827  Prepare budgets for approval, including those ...
#
#   Task Type  Incumbents Responding     Date Domain Source
# 0      Core                   87.0  07/2014     Incumbent
# 1      Core                   87.0  07/2014     Incumbent
# 2      Core                   87.0  07/2014     Incumbent
# 3      Core                   87.0  07/2014     Incumbent
# 4      Core                   87.0  07/2014     Incumbent

# %%
#Task DWAs (detailed work activitiy code):
taskDWA = pd.read_table(os.path.join(datasets, 'databases/db2016/Tasks to DWAs.txt'), sep='\t')
taskDWA = taskDWA[['Task ID', 'DWA ID']]

print(taskDWA.shape, "UNIQUE DWA: ", len(taskDWA['DWA ID'].unique()))
#Tasks to DWAs are many-to-many
taskDWA.head()
# Out:
# (22838, 2) UNIQUE DWA:  2070
#    Task ID             DWA ID
# 0    20461  4.A.2.a.4.I09.D03
# 1    20461  4.A.4.b.6.I08.D04
# 2     8823  4.A.4.b.4.I09.D02
# 3     8824  4.A.4.a.2.I03.D14
# 4     8825  4.A.2.a.4.I07.D09

# %%
df = pd.merge(tasks, taskDWA,  how='left', left_on=['Task ID'], right_on = ['Task ID']).sort_values(by = 'Task ID')
df = df[df['DWA ID'].notnull()]
df['IWA ID'] = df['DWA ID'].str.slice(0,-4)    # create IWA ID
df['WA ID'] = df['DWA ID'].str.slice(0,-8)     # create WA ID

## ADD DWA and IWA titles:
DWAref = pd.read_table(os.path.join(datasets, 'databases/db2016/DWA Reference.txt'), sep='\t')[['DWA ID', 'DWA Title']]
taskDWA2 = pd.merge(df, DWAref,  how='left', left_on=['DWA ID'], right_on = ['DWA ID'])

IWAref = pd.read_table(os.path.join(datasets, 'databases/db2016/IWA Reference.txt'), sep='\t')[['IWA ID', 'IWA Title']]
df2 = pd.merge(taskDWA2, IWAref,  how='left', left_on=['IWA ID'], right_on = ['IWA ID'])

# cols = ['Task ID', 'Task', 'DWA ID', 'DWA Title', 'IWA ID', 'IWA Title', 'WA ID']
cols = ['O*NET-SOC Code', 'Task ID', 'DWA ID', 'IWA ID', 'WA ID']
# df2 = df2[cols]

# tasks are many-to-many with DWA, e.g. task id=8826.
print(df2.shape, "UNIQUE DWA: ", len(df2['DWA ID'].unique()))
# Out:
# (22838, 12) UNIQUE DWA:  2070

# %%
pd.set_option('max_colwidth',200)

df2[df2["DWA ID"] == "4.A.4.b.4.I09.D08"]
# Out:
#       O*NET-SOC Code  Task ID  \
# 11840     21-2011.00    10949
# 11841     21-2011.00    10951
# 14094     21-2021.00    12986
# 22030     21-1015.00    20234
#
#                                                                                                                                                                                          Task  \
# 11840                                                                   Collaborate with committees or individuals to address financial or administrative issues pertaining to congregations.
# 11841  Perform administrative duties, such as overseeing building management, ordering supplies, contracting for services or repairs, or supervising the work of staff members or volunteers.
# 14094                                                                                                                   Analyze revenue and program cost data to determine budget priorities.
# 22030                                                                                              Manage budgets and direct case service allocations, authorizing expenditures and payments.
#
#           Task Type  Incumbents Responding     Date Domain Source  \
# 11840          Core                   88.0  07/2015     Incumbent
# 11841          Core                   88.0  07/2015     Incumbent
# 14094          Core                   94.0  07/2015     Incumbent
# 22030  Supplemental                  115.0  07/2012     Incumbent
#
#                   DWA ID         IWA ID      WA ID  \
# 11840  4.A.4.b.4.I09.D08  4.A.4.b.4.I09  4.A.4.b.4
# 11841  4.A.4.b.4.I09.D08  4.A.4.b.4.I09  4.A.4.b.4
# 14094  4.A.4.b.4.I09.D08  4.A.4.b.4.I09  4.A.4.b.4
# 22030  4.A.4.b.4.I09.D08  4.A.4.b.4.I09  4.A.4.b.4
#
#                                         DWA Title                    IWA Title
# 11840  Manage organizational or program finances.  Manage budgets or finances.
# 11841  Manage organizational or program finances.  Manage budgets or finances.
# 14094  Manage organizational or program finances.  Manage budgets or finances.
# 22030  Manage organizational or program finances.  Manage budgets or finances.

# %%
for soc in df2[df2["DWA ID"] == "4.A.4.b.4.I09.D08"]["O*NET-SOC Code"].unique():
    print(soc, occupations[occupations["O*NET-SOC Code"] == soc]["Occupation title"].unique())
    print(df2[df2["O*NET-SOC Code"] == soc]["DWA Title"].unique())
# Out:
# 21-2011.00 ['Clergy']
# ['Lead classes or community events.'
#  'Counsel clients or patients regarding personal issues.'
#  'Visit individuals in their homes to provide support or information.'
#  'Train staff members in social services skills.'
#  'Interpret cultural or religious information for others.'
#  'Intervene in crisis situations to assist clients.'
#  'Develop promotional strategies for religious organizations.'
#  'Manage organizational or program finances.'
#  'Refer clients to community or social service programs.'
#  'Develop educational programs.'
#  'Plan conferences, programs, or special events.']
# 21-2021.00 ['Directors, Religious Activities and Education']
# ['Supervise workers providing client or patient services.'
#  'Train staff members in social services skills.'
#  'Lead classes or community events.' 'Develop educational programs.'
#  'Plan conferences, programs, or special events.'
#  'Advise clients or community groups on health issues.'
#  'Counsel clients regarding interpersonal issues.'
#  'Counsel clients or patients regarding personal issues.'
#  'Assess individual or community needs for educational or social services.'
#  'Collaborate with other professionals to develop education or assistance programs.'
#  'Develop promotional strategies for religious organizations.'
#  'Present social services program information to the public.'
#  'Manage organizational or program finances.'
#  'Maintain professional social services knowledge.'
#  'Provide educational materials to community members.'
#  'Visit individuals in their homes to provide support or information.'
#  'Interpret cultural or religious information for others.']
# 21-1015.00 ['Rehabilitation Counselors']
# ['Monitor clients to evaluate treatment progress.'
#  'Maintain client records.'
#  'Confer with clients to discuss treatment plans or progress.'
#  'Arrange physical or mental health services for clients.'
#  'Evaluate characteristics of individuals to determine needs or eligibility.'
#  'Develop treatment plans for patients or clients.'
#  'Develop working relationships with others to facilitate program activities.'
#  'Evaluate potential problems in home or work environments of clients.'
#  'Assist clients in handling details of daily life.'
#  'Collaborate with other professionals to assess client needs or plan treatments.'
#  'Develop tools to diagnose or assess needs.'
#  'Refer individuals to educational or work programs.'
#  'Evaluate the effectiveness of counseling or educational programs.'
#  'Confer with family members to discuss client treatment plans or progress.'
#  'Collaborate with other professionals to develop education or assistance programs.'
#  'Manage organizational or program finances.']

# %%
df2[df2["WA ID"] == "4.A.4.b.4"]["DWA Title"].unique()
# Out:
# array(['Direct sales, marketing, or customer service activities.',
#        'Prepare operational budgets.',
#        'Manage human resources activities.', 'Supervise employees.',
#        'Direct administrative or support services.',
#        'Manage construction activities.',
#        'Direct facility maintenance or repair activities.',
#        'Direct organizational operations, projects, or services.',
#        'Manage control system activities in organizations.',
#        'Coordinate special events or programs.',
#        'Direct financial operations.',
#        'Prepare staff schedules or work assignments.',
#        'Manage operations, research, or logistics projects.',
#        'Coordinate training activities.',
#        'Coordinate personnel recruitment activities.',
#        'Supervise engineering or other technical personnel.',
#        'Direct design or development activities.',
#        'Supervise scientific or technical personnel.',
#        'Manage agricultural or forestry operations.',
#        'Direct natural resources management or conservation programs.',
#        'Supervise workers providing client or patient services.',
#        'Manage operations of artistic or entertainment departments or organizations.',
#        'Coordinate artistic activities.', 'Coordinate design activities.',
#        'Manage preparation of special meals or diets.',
#        'Manage healthcare operations.',
#        'Supervise medical support personnel.',
#        'Direct healthcare delivery programs.',
#        'Supervise patient care personnel.',
#        'Direct criminal investigations.',
#        'Direct law enforcement activities.',
#        'Prepare activity or work schedules.',
#        'Supervise service workers.',
#        'Assign duties or work schedules to employees.',
#        'Supervise sales or support personnel.',
#        'Coordinate sales campaigns.',
#        'Arrange delivery of goods or services.',
#        'Prepare employee work schedules.',
#        'Supervise clerical or administrative personnel.',
#        'Coordinate construction project activities.',
#        'Direct construction or extraction personnel.',
#        'Direct operational or production activities.',
#        'Manage organizational or project budgets.',
#        'Manage guest services.', 'Organize special events.',
#        'Oversee business processes.',
#        'Coordinate regulatory documentation activities.',
#        'Manage information technology projects or system activities.',
#        'Supervise information technology personnel.',
#        'Coordinate project activities with other personnel or departments.',
#        'Coordinate software or hardware installation.',
#        'Coordinate resource procurement activities.',
#        'Direct quality control activities.',
#        'Direct construction activities.',
#        'Direct installation activities.',
#        'Direct equipment maintenance or repair activities.',
#        'Direct industrial production activities.',
#        'Prepare project budgets.',
#        'Direct environmental development activities.',
#        'Coordinate safety or regulatory compliance activities.',
#        'Direct technical activities or operations.',
#        'Manage scientific or technical project resources.',
#        'Coordinate legal schedules or activities.',
#        'Direct activities of subordinates.',
#        'Coordinate construction or installation activities.',
#        'Coordinate athletic or sporting events or activities.',
#        'Coordinate logistics for productions or events.',
#        'Coordinate activities of production personnel.',
#        'Coordinate reporting or editing activities.',
#        'Manage content of broadcasts or presentations.',
#        'Supervise technical medical personnel.',
#        'Supervise inmate activities.',
#        'Direct operations of correctional facilities.',
#        'Coordinate activities of food service staff.',
#        'Manage food service operations or parts of operations.',
#        'Coordinate timing of food production activities.',
#        'Organize recreational activities or events.',
#        'Coordinate operational activities.',
#        'Coordinate shipping activities with external parties.',
#        'Manage clerical or administrative activities.',
#        'Direct funeral or mortuary activities.',
#        'Manage financial activities of the organization.',
#        'Direct surveying activities.',
#        'Direct energy production or management activities.',
#        'Supervise production or support personnel.',
#        'Supervise activities of other legal personnel.',
#        'Direct department activities.',
#        'Direct productions or performances.',
#        'Direct fundraising or financing activities.', 'Host events.',
#        'Direct fire fighting or prevention activities.',
#        'Direct employee training programs.',
#        'Direct security operations.',
#        'Manage budgets for personal services operations.',
#        'Direct material handling or moving activities.',
#        'Manage outreach activities.',
#        'Direct medical science or healthcare programs.',
#        'Coordinate cross-disciplinary research programs.',
#        'Direct scientific activities.',
#        'Direct courtroom activities or procedures.',
#        'Serve on institutional or departmental committees.',
#        'Supervise student research or internship work.',
#        'Supervise laboratory work.',
#        'Coordinate student extracurricular activities.',
#        'Assign class work to students.',
#        'Manage budgets for appropriate resource allocation.',
#        'Supervise trainees.', 'Supervise maintenance workers.',
#        'Direct passenger or freight transport activities.',
#        'Direct emergency management activities.',
#        'Coordinate logistics or other business operations.',
#        'Coordinate enforcement of laws or regulations.',
#        'Direct natural resources extraction projects.',
#        'Coordinate musical rehearsals or performances.',
#        'Count prison inmates or personnel.',
#        'Plan employee work schedules.',
#        'Coordinate flight control or management activities.',
#        'Direct maintenance or repair activities.',
#        'Manage organizational or program finances.',
#        'Coordinate forestry or agricultural activities.',
#        'Direct activities of agricultural, forestry, or fishery employees.',
#        'Manage documentation to ensure organization or accuracy.',
#        'Supervise workers performing environmentally sustainable activities.',
#        'Direct green energy production operations.',
#        'Prepare operational budgets for green energy or other green operations.',
#        'Direct maintenance and repair activities in green energy production facilities.',
#        'Manage environmental sustainability projects.',
#        'Manage organizational security activities.'], dtype=object)
