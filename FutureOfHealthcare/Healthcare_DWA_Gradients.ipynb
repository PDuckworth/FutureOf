# %% [markdown]
# ## Compute the Average Gradients of the Healthcare Tasks

# %%
# encoding=utf8
import os
import numpy as np
import pandas as pd
import getpass
import pickle
import string
import matplotlib.pyplot as plt
from matplotlib import rc
rc('font',**{'family': 'serif', 'serif':"Computer Modern Roman"})
rc('text', usetex=True)
# %matplotlib inline

# %%
## # Input DATA set of observed Occupations and Tasks
datasets = '/home/'+ getpass.getuser() +'/Datasets/'
d = os.path.join(datasets, 'FoHealthcare/Final_dataset_06112018.xlsx')

excel_doc = pd.ExcelFile(d)
dataset = excel_doc.parse(sheet_name='ExpandedTasks')
dataset = dataset[dataset['clinical'] != 1]   # # REMOVE CLINICAL TASKS: 
print("All Task-Occu pairs: %s" % str(dataset.shape[0]))


task_dataset = excel_doc.parse(sheet_name='Tasks')
task_dataset = task_dataset[task_dataset['clinical'] != 1]
print("unique clerical tasks dataset:", task_dataset.shape)
# Out:
# All Task-Occu pairs: 264
# unique clerical tasks dataset: (108, 23)

# %%
keep_hc_cols = ['Observed Occupation', 'Task', 'DWA Task', 'DWA ID', 'Task Weight', 'Automation Scores',
       'Weighted Average Automation Score']
HC_data = dataset[keep_hc_cols]
task_dataset = task_dataset[keep_hc_cols]
print("Tasks dataset: %s" % len(task_dataset["Task"]))
print("HC data: %s" % len(HC_data["Task"]))
unique_occupations = dataset["Observed Occupation"].unique()
HC_data.head()
# Out:
# Tasks dataset: 108
# HC data: 264
#   Observed Occupation                                               Task  \
# 0       Administrator          Address problems that arise with building
# 1       Administrator                                       Answer phone
# 2       Administrator                   Checking for errors in paperwork
# 3       Administrator  Cleaning up information in the patients electr...
# 4       Administrator  Connecting human resources/making introduction...
#
#                                             DWA Task  \
# 0  Notify others of emergencies, problems, or haz...
# 1  Answer telephones to direct calls or provide i...
# 2                   Check data for recording errors.
# 3                      Process healthcare paperwork.
# 4               Relay information between personnel.
#
#                                               DWA ID  \
# 0  4.A.4.a.2.I08.D07; 4.A.4.a.2.I08.D04; 4.A.4.a....
# 1                                  4.A.4.a.3.I03.D11
# 2                                  4.A.2.a.2.I01.D08
# 3                                  4.A.4.c.1.I01.D03
# 4                                  4.A.4.a.2.I03.D11
#
#                       Task Weight               Automation Scores  \
# 0   0.20; 0.20; 0.20; 0.20; 0.20;   2.92; 3.08; 3.52; 3.29; 2.72;
# 1                           1.00;                           3.36;
# 2                           1.00;                           3.33;
# 3                           1.00;                           2.78;
# 4                           1.00;                           3.27;
#
#    Weighted Average Automation Score
# 0                           3.105316
# 1                           3.361812
# 2                           3.329314
# 3                           2.782653
# 4                           3.268373

# %%
def risk_cat(score):
    return int(np.floor(score))

# Add the risk category as a new column
task_dataset["cat_n"] = task_dataset["Weighted Average Automation Score"].apply(lambda col: risk_cat(col))
low = task_dataset[task_dataset["cat_n"] == 1]
med = task_dataset[task_dataset["cat_n"] == 2]
high = task_dataset[task_dataset["cat_n"] == 3]
print("These are our sets to calcluate gradients over: ", low.shape, med.shape, high.shape)
low
# Out:
# These are our sets to calcluate gradients over:  (6, 8) (55, 8) (47, 8)
#      Observed Occupation                                               Task  \
# 48  Healthcare Assistant                   Print out lab test labels in ICE
# 61          Phlebotomist                                  Label blood vials
# 68      Practice Manager  Manage finances for the practice including pay...
# 72      Practice Manager                                  Staff recruitment
# 75      Practice Manager                      Writing and updating policies
# 80      Practice Manager         Having practice staff take online training
#
#                                              DWA Task  \
# 48               Apply identification labels or tags.
# 61               Apply identification labels or tags.
# 68  Manage organizational or program finances.; Ma...
# 72                                 Recruit personnel.
# 75  Evaluate effectiveness of personnel policies o...
# 80  Coordinate training activities.; Direct employ...
#
#                                   DWA ID   Task Weight Automation Scores  \
# 48                     4.A.1.b.1.I01.D01         1.00;             1.76;
# 61                     4.A.1.b.1.I01.D01         1.00;             1.76;
# 68  4.A.4.b.4.I09.D08; 4.A.4.b.4.I09.D06   0.50; 0.50;       1.44; 2.23;
# 72                     4.A.4.c.2.I01.D05         1.00;             1.82;
# 75                     4.A.2.a.1.I02.D04         1.00;             1.96;
# 80  4.A.4.b.4.I07.D01; 4.A.4.b.4.I07.D03   0.50; 0.50;       1.16; 2.66;
#
#     Weighted Average Automation Score  cat_n
# 48                           1.760170      1
# 61                           1.760170      1
# 68                           1.832718      1
# 72                           1.824356      1
# 75                           1.958048      1
# 80                           1.907981      1

# %%
infile = open('aies_data/average_gradients.pkl','rb')
average_gradients = pickle.load(infile)
infile.close()

infile = open('aies_data/dwa_order.pkl','rb')
dwa_order = pickle.load(infile)
infile.close()

infile = open('aies_data/all_pointwise_gradients.pkl','rb')
pointwise_gradients = pickle.load(infile)
infile.close()

infile = open('aies_data/feature_order.pkl','rb')
feature_order = pickle.load(infile)
infile.close()

# Load all the gradient information from AIES repo ... 
print(average_gradients.shape, pointwise_gradients.shape, feature_order[:10], dwa_order[:5])

dwa_grads = pd.DataFrame(data = pointwise_gradients, columns=feature_order)
dwa_grads["DWA ID"] = pd.Series([i[0] for i in dwa_order])
# Out:
# (120,) (2067, 120) ['Active Learning', 'Active Listening', 'Complex Problem Solving', 'Coordination', 'Critical Thinking', 'Equipment Maintenance', 'Equipment Selection', 'Installation', 'Instructing', 'Judgment and Decision Making'] [['4.A.1.a.1.I01.D01']
#  ['4.A.1.a.1.I01.D04']
#  ['4.A.1.a.1.I02.D08']
#  ['4.A.1.a.1.I02.D09']
#  ['4.A.1.a.1.I02.D10']]

# %%
with open("aies_data/ibcc_train_test_data.pkl", 'rb') as f:
    data = pickle.load(f)
f.close()

X, y = data[0].iloc[:, 1:-2].values, data[2].iloc[:, 0].values
X_test = data[1].iloc[:, 1:].values
y = np.round(y * 2.) / 2.
features = list(data[0].iloc[:, 1:-2].columns)

X_all = np.vstack([X, X_test])
dwas = np.vstack([data[0].iloc[:, 0].values.reshape(-1, 1), data[1].iloc[:, 0].values.reshape(-1, 1)])

dwa_feats = pd.DataFrame(data=X_all, columns=feature_order)
dwa_feats["DWA ID"] = pd.Series([i[0] for i in dwa_order])
dwa_feats.head()
# Out:
#    Active Learning  Active Listening  Complex Problem Solving  Coordination  \
# 0         3.206031          3.798952                 3.308485      3.255014
# 1         3.241681          3.920024                 3.189726      3.530566
# 2         3.151530          3.621651                 3.387262      3.101375
# 3         2.692799          3.073483                 2.878213      3.096213
# 4         2.791359          3.322016                 3.040584      3.132688
#
#    Critical Thinking  Equipment Maintenance  Equipment Selection  \
# 0           3.465971               1.352048             1.586345
# 1           3.621624               1.091567             1.192623
# 2           3.626099               1.573449             1.762136
# 3           3.190303               2.117181             2.339092
# 4           3.338834               2.130404             1.735284
#
#    Installation  Instructing  Judgment and Decision Making        ...          \
# 0      1.043563     2.842514                      3.411688        ...
# 1      1.053746     3.022365                      3.459405        ...
# 2      1.336109     2.818544                      3.308758        ...
# 3      1.657604     2.499585                      2.945194        ...
# 4      1.215225     2.635423                      3.108596        ...
#
#     Stamina  Static Strength  Time Sharing  Trunk Strength  \
# 0  1.153341         1.217814      2.520910        1.451737
# 1  1.839739         1.700592      2.768509        1.993082
# 2  1.301533         1.415211      2.663005        1.708003
# 3  2.835105         3.150562      2.622120        3.293398
# 4  2.295489         2.602196      2.747473        2.551150
#
#    Visual Color Discrimination  Visualization  Wrist-Finger Speed  \
# 0                     3.352828       3.520535            1.413655
# 1                     2.454878       2.957088            1.224493
# 2                     2.827332       3.327724            1.693029
# 3                     2.718646       3.235995            2.032858
# 4                     2.789201       2.908992            2.024323
#
#    Written Comprehension  Written Expression             DWA ID
# 0               3.788355            3.342607  4.A.1.a.1.I01.D01
# 1               3.841295            3.437580  4.A.1.a.1.I01.D04
# 2               3.825821            3.568996  4.A.1.a.1.I02.D08
# 3               2.935040            2.543448  4.A.1.a.1.I02.D09
# 4               3.251757            3.052460  4.A.1.a.1.I02.D10
#
# [5 rows x 121 columns]

# %%
low.head()
# Out:
#      Observed Occupation                                               Task  \
# 48  Healthcare Assistant                   Print out lab test labels in ICE
# 61          Phlebotomist                                  Label blood vials
# 68      Practice Manager  Manage finances for the practice including pay...
# 72      Practice Manager                                  Staff recruitment
# 75      Practice Manager                      Writing and updating policies
#
#                                              DWA Task  \
# 48               Apply identification labels or tags.
# 61               Apply identification labels or tags.
# 68  Manage organizational or program finances.; Ma...
# 72                                 Recruit personnel.
# 75  Evaluate effectiveness of personnel policies o...
#
#                                   DWA ID   Task Weight Automation Scores  \
# 48                     4.A.1.b.1.I01.D01         1.00;             1.76;
# 61                     4.A.1.b.1.I01.D01         1.00;             1.76;
# 68  4.A.4.b.4.I09.D08; 4.A.4.b.4.I09.D06   0.50; 0.50;       1.44; 2.23;
# 72                     4.A.4.c.2.I01.D05         1.00;             1.82;
# 75                     4.A.2.a.1.I02.D04         1.00;             1.96;
#
#     Weighted Average Automation Score  cat_n
# 48                           1.760170      1
# 61                           1.760170      1
# 68                           1.832718      1
# 72                           1.824356      1
# 75                           1.958048      1

# %%
dwa_feats[dwa_feats["DWA ID"]=="4.A.4.b.4.I09.D06"]
# Out:
#       Active Learning  Active Listening  Complex Problem Solving  \
# 1880             3.38              3.75                      4.0
#
#       Coordination  Critical Thinking  Equipment Maintenance  \
# 1880          3.12               4.25                    1.0
#
#       Equipment Selection  Installation  Instructing  \
# 1880                  1.0           1.0         2.88
#
#       Judgment and Decision Making        ...          Stamina  \
# 1880                          4.25        ...              1.0
#
#       Static Strength  Time Sharing  Trunk Strength  \
# 1880              1.0           2.5            1.25
#
#       Visual Color Discrimination  Visualization  Wrist-Finger Speed  \
# 1880                         2.12           2.75                1.12
#
#       Written Comprehension  Written Expression             DWA ID
# 1880                   3.88                 3.5  4.A.4.b.4.I09.D06
#
# [1 rows x 121 columns]

# %%
# # # These are the column name groupings... (used in the latex outputs)
cols = feature_order
skills = cols[:35]
knowledges = cols[35:68]
abilities = cols[68:]

characteristic_dict = {}
for i in skills:
    characteristic_dict[i] = "skill"
for i in knowledges:
    characteristic_dict[i] = "knowledge"
for i in abilities:
    characteristic_dict[i] = "ability"
# characteristic_dict


def print_top(col_name, cap):
     print("\\begin{table}[h!] \
    \\caption{%s} \
    \\centering \\small \
    \\begin{tabular}{@{}lc@{}} \\toprule{}  \
    O*NET Feature & %s  \\\\  \\midrule" % (cap, col_name))

def print_bot(label):
    print("\\bottomrule \
    \\end{tabular} \
    \\label{tab:%s} \
    \\end{table}" % label)
    return

# %%
# number_of_features_presented = 5

# for subset_of_data, risk in zip([low, high, med], ["not-automatable", "automatable", "partly-automatable"]):
#     print("\n %%", risk, subset_of_data.shape)
    
#     avg_features, dwa_grads_per_set = [],[]
#     for index, row in subset_of_data.iterrows():
#         dwas = [i.strip() for i in row['DWA ID'].split(";")]
# #         print(dwas)

#         weights = [i.strip() for i in row['Task Weight'].split(";")]
        
#         feat_subset = dwa_feats[dwa_feats["DWA ID"].isin(dwas)][cols].values  # FYI: this is not ordered the same as "dwas"
#         grad_subset = dwa_grads[dwa_grads["DWA ID"].isin(dwas)][cols].values  # FYI: this is not ordered the same as "dwas" 
# #         print(grad_subset)
# #         print(feat_subset)
    
#         avg_features.append(feat_subset.mean(axis=0)) 
#         dwa_grads_per_set.append(grad_subset.mean(axis=0)) 
        
#     average_grads = np.vstack(dwa_grads_per_set).mean(axis=0)
#     avg_features =  np.vstack(avg_features).mean(axis=0)


#     # # These are the characteristics of those tasks (in the sub-set)
#     neg_grads  = [(col, grad) for col, grad in sorted(zip(average_grads, cols))][:number_of_features_presented]
# #     poss_grads = [(col, grad) for col, grad in sorted(zip(average_grads, cols))][-number_of_features_presented:]  ## This means they are sorted differently (but gives you the same set of 10)
#     poss_grads = [(col, grad) for col, grad in sorted(zip(average_grads, cols), reverse=True)][:number_of_features_presented]

    
#     ### Print the results to latex:
#     print("\n %% AVERAGE FEATURE DIFFERENCES:")
#     caption = "Largest feature differences relative to the population for \\textcolor{vubbleu}{%s} healthcare tasks" % risk
#     print_top("Feature Difference", caption)
#     mean_dataset_features = dwa_feats.mean(axis=0)
#     percentage_diffs = ((avg_features - mean_dataset_features) / mean_dataset_features)*100
    
#     # # REMOVED THE NEGATIVE FEATURES
# #     for i, j in sorted(zip(percentage_diffs, cols))[:number_of_features_presented]:
# #         print(j , "(%s) & \\SI{%0.1f}{\\percent}  \\\\ " % (characteristic_dict[j], i)) 
#     for i, j in sorted(zip( percentage_diffs, cols), reverse=True)[:number_of_features_presented]:
#         print(j , "(%s) & +\\SI{%0.1f}{\\percent}  \\\\ " % (characteristic_dict[j], i)) 
#     print("\\midrule")
#     label = "tab:feature_diff_%s" % risk
#     print_bot(label)
        
    
#     print("\n %% AVERAGE FEATURE GRADIENTS:")    
#     caption = "O*NET features with the largest (possitive and negative) derivatives for \\textcolor{vubbleu}{%s} healthcare tasks." % risk
#     print_top("Feature Gradient", caption)
    
#  # # REMOVED THE NEGATIVE FEATURES
# #     for (i, j) in neg_grads:
# #         print(j , "(%s) & %0.3f  \\\\ " % (characteristic_dict[j], i)) 
    
#     for (i, j) in poss_grads:
#         print(j , "(%s) & +%0.3f  \\\\ " % (characteristic_dict[j], i))
#     print("\\midrule")
#     label = "tab:feature_grad_%s" % risk    
#     print_bot(label)

# %% [markdown]
# ## Just two tables instead of threex2:

# %%
def print_top2(col_name, cap):
     print("\\begin{table}[h!] \
    \\caption{%s} \
    \\centering \\small \
    \\begin{tabular}{@{}llc@{}} \\toprule{}  \
    \\textbf{Risk Category} & \\textbf{O*NET Feature} & \\textbf{%s}  \\\\  \\midrule" % (cap, col_name))

# %%
print("%% taken from Healthcare_DWA_Gradients.ipynb,\n")

number_of_features_presented = 5

caption = "Largest feature differences relative to the dataset by risk category"
print_top2("Feature Difference", caption)
for cnt, (subset_of_data, risk) in enumerate(zip([low, high, med ], ["not-automatable", "automatable", "partly-automatable"])):
    print("\n %%", risk, subset_of_data.shape)
    
    avg_features, dwa_grads_per_set = [],[]
    for index, row in subset_of_data.iterrows():
        dwas = [i.strip() for i in row['DWA ID'].split(";")]
#         print(dwas)


        weights = [i.strip() for i in row['Task Weight'].split(";")]
        feat_subset = dwa_feats[dwa_feats["DWA ID"].isin(dwas)][cols].values  # FYI: this is not ordered the same as "dwas"
        grad_subset = dwa_grads[dwa_grads["DWA ID"].isin(dwas)][cols].values  # FYI: this is not ordered the same as "dwas" 
#         print(grad_subset)
#         print(feat_subset)
    
        avg_features.append(feat_subset.mean(axis=0)) 
        dwa_grads_per_set.append(grad_subset.mean(axis=0)) 
        
    average_grads = np.vstack(dwa_grads_per_set).mean(axis=0)
    avg_features =  np.vstack(avg_features).mean(axis=0)


    # # These are the characteristics of those tasks (in the sub-set)
    neg_grads  = [(col, grad) for col, grad in sorted(zip(average_grads, cols))][:number_of_features_presented]
#     poss_grads = [(col, grad) for col, grad in sorted(zip(average_grads, cols))][-number_of_features_presented:]  ## This means they are sorted differently (but gives you the same set of 10)
    poss_grads = [(col, grad) for col, grad in sorted(zip(average_grads, cols), reverse=True)][:number_of_features_presented]

    print("\n %% AVERAGE FEATURE DIFFERENCES:")
    mean_dataset_features = dwa_feats.mean(axis=0)
    percentage_diffs = ((avg_features - mean_dataset_features) / mean_dataset_features)*100
    for ind, (i, j) in enumerate(sorted(zip( percentage_diffs, cols), reverse=True)[:number_of_features_presented]):
        if ind==0:
            print(risk, " & ", j , "(%s) & +\\SI{%0.1f}{\\percent}  \\\\ " % (characteristic_dict[j], i)) 
        else:
            print(" & ",j , "(%s) & +\\SI{%0.1f}{\\percent}  \\\\ " % (characteristic_dict[j], i))   

#         REMOVE NEGATIVE FEATURES
#     print("\\cdashline{2-3}")       
#     for i, j in sorted(zip(percentage_diffs, cols))[:number_of_features_presented]:
#             print(" & ", j , "(%s) & \\SI{%0.1f}{\\percent}  \\\\ " % (characteristic_dict[j], i)) 

    if cnt != 2: print("\\midrule")
label = "feature_diffs"
print_bot(label)

print("\n")

 # # #  JUST THE SAME LOOP AGAIN BECUASE IM LAZY...
 
# caption = "O*NET features with the largest average derivatives by risk category"
# print_top2("Feature Gradient", caption)
# for cnt, (subset_of_data, risk) in enumerate(zip([low, high, med ], ["not-automatable", "automatable", "partly-automatable"])):
#     print("\n %%", risk, subset_of_data.shape)
    
#     avg_features, dwa_grads_per_set = [],[]
#     for index, row in subset_of_data.iterrows():
#         dwas = [i.strip() for i in row['DWA ID'].split(";")]
#         weights = [i.strip() for i in row['Task Weight'].split(";")]
       
#         feat_subset = dwa_feats[dwa_feats["DWA ID"].isin(dwas)][cols].values  # FYI: this is not ordered the same as "dwas"
#         grad_subset = dwa_grads[dwa_grads["DWA ID"].isin(dwas)][cols].values  # FYI: this is not ordered the same as "dwas" 
   
#         avg_features.append(feat_subset.mean(axis=0)) 
#         dwa_grads_per_set.append(grad_subset.mean(axis=0)) 
        
#     average_grads = np.vstack(dwa_grads_per_set).mean(axis=0)
#     avg_features =  np.vstack(avg_features).mean(axis=0) 
        

#     # # These are the characteristics of those tasks (in the sub-set)
#     neg_grads  = [(col, grad) for col, grad in sorted(zip(average_grads, cols))][:number_of_features_presented]
# #     poss_grads = [(col, grad) for col, grad in sorted(zip(average_grads, cols))][-number_of_features_presented:]  ## This means they are sorted differently (but gives you the same set of 10)
#     poss_grads = [(col, grad) for col, grad in sorted(zip(average_grads, cols), reverse=True)][:number_of_features_presented]

#     ### Print the results to latex:
#     print("\n %% AVERAGE FEATURE GRADIENTS:")    

#     for ind, (i, j) in enumerate(poss_grads):
#         if ind==0:
#             print(risk, " & ",  j , "(%s) & +%0.3f  \\\\ " % (characteristic_dict[j], i))
#         else:
#             print(" & ", j , "(%s) & +%0.3f  \\\\ " % (characteristic_dict[j], i))
            
# #         REMOVE NEGATIVE FEATURES            
# #     print("\\cdashline{2-3}")  
# #     for (i, j) in neg_grads:
# #         print(" & ", j , "(%s) & %0.3f  \\\\ " % (characteristic_dict[j], i)) 


#     if cnt != 2: print("\\midrule")
# label = "feature_grads"
# print_bot(label)
# Out:
# %% taken from Healthcare_DWA_Gradients.ipynb,
#
# \begin{table}[h!]     \caption{Largest feature differences relative to the dataset by risk category}     \centering \small     \begin{tabular}{@{}llc@{}} \toprule{}      \textbf{Risk Category} & \textbf{O*NET Feature} & \textbf{Feature Difference}  \\  \midrule
#
#  %% not-automatable (6, 8)
#
#  %% AVERAGE FEATURE DIFFERENCES:
# not-automatable  &  Installation (skill) & +\SI{62.6}{\percent}  \\
#  &  Building and Construction (knowledge) & +\SI{27.2}{\percent}  \\
#  &  Personnel and Human Resources (knowledge) & +\SI{26.0}{\percent}  \\
#  &  Management of Financial Resources (skill) & +\SI{18.7}{\percent}  \\
#  &  Education and Training (knowledge) & +\SI{17.0}{\percent}  \\
# \midrule
#
#  %% automatable (47, 8)
#
#  %% AVERAGE FEATURE DIFFERENCES:
# automatable  &  Clerical (knowledge) & +\SI{24.4}{\percent}  \\
#  &  Customer and Personal Service (knowledge) & +\SI{13.2}{\percent}  \\
#  &  Service Orientation (skill) & +\SI{5.0}{\percent}  \\
#  &  Economics and Accounting (knowledge) & +\SI{4.7}{\percent}  \\
#  &  Computers and Electronics (knowledge) & +\SI{4.5}{\percent}  \\
# \midrule
#
#  %% partly-automatable (55, 8)
#
#  %% AVERAGE FEATURE DIFFERENCES:
# partly-automatable  &  Medicine and Dentistry (knowledge) & +\SI{30.8}{\percent}  \\
#  &  Therapy and Counseling (knowledge) & +\SI{22.0}{\percent}  \\
#  &  Psychology (knowledge) & +\SI{13.4}{\percent}  \\
#  &  Clerical (knowledge) & +\SI{13.2}{\percent}  \\
#  &  Biology (knowledge) & +\SI{12.1}{\percent}  \\
# \bottomrule     \end{tabular}     \label{tab:feature_diffs}     \end{table}

# %%
def print_top3(col_name, cap):
     print("\\begin{table}[h!] \
    \\caption*{%s} \
    \\centering \\small \
    \\begin{tabular}{@{}lc@{}} \
    \\textbf{O*NET Feature} & \\textbf{%s}  \\\\  \\midrule" % (cap, col_name))
        
def print_3_task_table(data, occu, cap, label, max_length = 55):
    display_number_of_tasks = 3
    
    display_cols = ["Task", "Weighted Average Automation Score"]
    dataset_tasks = data.sort_values(by="Weighted Average Automation Score")

    low = dataset_tasks.iloc[:display_number_of_tasks,:][display_cols]
    high = dataset_tasks.iloc[-display_number_of_tasks:,:].iloc[::-1][display_cols]
    

    print("\\begin{center} \
    \\begin{longtable}[t]{K{.1\linewidth}K{.6\linewidth}C{.15\linewidth}} \
    \\caption*{%s} \\label{%s} \\\\ \
    \\small \
       & \\textbf{Task} & \\textbf{Automation Score}  \\\\  \\midrule" % (cap, label))
 
    for cnt, (i, row) in enumerate(low.iterrows()):
        if cnt == 0:
            print("Lowest & %s & %0.3f \\\\" % (row[0], row[1] ) )
        else:
            print(" & %s & %0.3f \\\\" % (row[0], row[1] ) )
    print("\\cdashline{2-3}")
    
    for cnt, (i, row) in enumerate(high.iterrows()):
        if cnt == 0:
            print("Highest & %s & %0.3f \\\\" % (row[0], row[1] ) )    
        else:
            print(" &  %s & %0.3f \\\\" % (row[0], row[1] ) )

    print("\\bottomrule \
    \\end{longtable} \
    \end{center} \
    ")
    return

# %% [markdown]
# ## This is Appendix data:

# %%
print("%% taken from Healthcare_DWA_Gradients.ipynb,\n")

number_of_features_presented = 5

for occu in unique_occupations:
    subset_of_data = HC_data[HC_data["Observed Occupation"] == occu]
    
    risk = occu.replace(" ","_")
    print("\n %%", risk, subset_of_data.shape)
    print("\\subsubsection*{%s}" % occu)
    
    # # In here - put the 3 most, and the 3 least automatable tasks... 
    caption = "\\textcolor{vubbleu}{%s}: Three most and least automatable tasks" % occu
    label = "app:tab:3tasks_%s" % risk
    print_3_task_table(subset_of_data, occu, caption, label)
    
    
    avg_features, dwa_grads_per_set = [],[]
    for index, row in subset_of_data.iterrows():
        dwas = [i.strip() for i in row['DWA ID'].split(";")]
        weights = [i.strip() for i in row['Task Weight'].split(";")]
        feat_subset = dwa_feats[dwa_feats["DWA ID"].isin(dwas)][cols].values  # FYI: this is not ordered the same as "dwas"
        grad_subset = dwa_grads[dwa_grads["DWA ID"].isin(dwas)][cols].values  # FYI: this is not ordered the same as "dwas" 
   
        avg_features.append(feat_subset.mean(axis=0)) 
        dwa_grads_per_set.append(grad_subset.mean(axis=0)) 
        
    average_grads = np.vstack(dwa_grads_per_set).mean(axis=0)
    avg_features =  np.vstack(avg_features).mean(axis=0) 
        
    # # These are the characteristics of those tasks (in the sub-set)
    neg_grads  = [(col, grad) for col, grad in sorted(zip(average_grads, cols))][:number_of_features_presented]
#     poss_grads = [(col, grad) for col, grad in sorted(zip(average_grads, cols))][-number_of_features_presented:]  ## This means they are sorted differently (but gives you the same set of 10)
    poss_grads = [(col, grad) for col, grad in sorted(zip(average_grads, cols), reverse=True)][:number_of_features_presented]
   
    
    ### Print the results to latex:
    print("\n %% AVERAGE FEATURE DIFFERENCES:")
    caption = "\\textcolor{vubbleu}{%s}: Largest feature differences relative to the population" % occu
    print_top3("Feature Difference", caption)
    mean_dataset_features = dwa_feats.mean(axis=0)
    percentage_diffs = ((avg_features - mean_dataset_features) / mean_dataset_features)*100    
    for i, j in sorted(zip( percentage_diffs, cols), reverse=True)[:number_of_features_presented]:
        print(j.replace("_", "\_")  , "(%s) & +\\SI{%0.1f}{\\percent}  \\\\ " % (characteristic_dict[j], i)) 
    print("\\midrule")    
    for i, j in sorted(zip(percentage_diffs, cols))[:number_of_features_presented]:
        print(j.replace("_", "\_")  , "(%s) & \\SI{%0.1f}{\\percent}  \\\\ " % (characteristic_dict[j], i)) 
    label = "tab:feature_diff_%s" % risk
    print_bot(label)
        
    
    print("\n %% AVERAGE FEATURE GRADIENTS:")    
    caption = "\\textcolor{vubbleu}{%s}: O*NET features with the largest (positive and negative) derivatives." % occu
    print_top3("Feature Gradient", caption)
    for (i, j) in neg_grads:
        print(j.replace("_", "\_")  , "(%s) & %0.3f  \\\\ " % (characteristic_dict[j], i)) 
    print("\\midrule")        
    for (i, j) in poss_grads:
        print(j.replace("_", "\_")  , "(%s) & +%0.3f  \\\\ " % (characteristic_dict[j], i))
    label = "tab:feature_grad_%s" % risk    
    print_bot(label)
    
    print("\\newpage")
# Out:
# %% taken from Healthcare_DWA_Gradients.ipynb,
#
#
#  %% Administrator (40, 7)
# \subsubsection*{Administrator}
# \begin{center}     \begin{longtable}[t]{K{.1\linewidth}K{.6\linewidth}C{.15\linewidth}}     \caption*{\textcolor{vubbleu}{Administrator}: Three most and least automatable tasks} \label{app:tab:3tasks_Administrator} \\     \small        & \textbf{Task} & \textbf{Automation Score}  \\  \midrule
# Lowest & Staff recruitment & 1.824 \\
#  & Manage pension schemes & 2.108 \\
#  & Write notes on paper & 2.235 \\
# \cdashline{2-3}
# Highest & Mass mail letters for checkups using DocMail & 3.725 \\
#  &  Print letters & 3.609 \\
#  &  Use texting service or patient management service to contact patients for different clinics and to send reminders. & 3.604 \\
# \bottomrule     \end{longtable}     \end{center}
#
#  %% AVERAGE FEATURE DIFFERENCES:
# \begin{table}[h!]     \caption*{\textcolor{vubbleu}{Administrator}: Largest feature differences relative to the population}     \centering \small     \begin{tabular}{@{}lc@{}}     \textbf{O*NET Feature} & \textbf{Feature Difference}  \\  \midrule
# Clerical (knowledge) & +\SI{20.1}{\percent}  \\
# Customer and Personal Service (knowledge) & +\SI{10.0}{\percent}  \\
# Computers and Electronics (knowledge) & +\SI{6.9}{\percent}  \\
# Service Orientation (skill) & +\SI{6.3}{\percent}  \\
# English Language (knowledge) & +\SI{6.2}{\percent}  \\
# \midrule
# Mechanical (knowledge) & \SI{-27.2}{\percent}  \\
# Building and Construction (knowledge) & \SI{-26.1}{\percent}  \\
# Repairing (skill) & \SI{-25.5}{\percent}  \\
# Troubleshooting (skill) & \SI{-24.4}{\percent}  \\
# Equipment Maintenance (skill) & \SI{-24.2}{\percent}  \\
# \bottomrule     \end{tabular}     \label{tab:tab:feature_diff_Administrator}     \end{table}
#
#  %% AVERAGE FEATURE GRADIENTS:
# \begin{table}[h!]     \caption*{\textcolor{vubbleu}{Administrator}: O*NET features with the largest (positive and negative) derivatives.}     \centering \small     \begin{tabular}{@{}lc@{}}     \textbf{O*NET Feature} & \textbf{Feature Gradient}  \\  \midrule
# Programming (skill) & -0.178  \\
# Technology Design (skill) & -0.164  \\
# Fine Arts (knowledge) & -0.152  \\
# Installation (skill) & -0.148  \\
# Food Production (knowledge) & -0.124  \\
# \midrule
# Clerical (knowledge) & +0.174  \\
# Telecommunications (knowledge) & +0.163  \\
# Wrist-Finger Speed (ability) & +0.158  \\
# Number Facility (ability) & +0.125  \\
# Building and Construction (knowledge) & +0.103  \\
# \bottomrule     \end{tabular}     \label{tab:tab:feature_grad_Administrator}     \end{table}
# \newpage
#
#  %% Deputy_Practice_Manager (33, 7)
# \subsubsection*{Deputy Practice Manager}
# \begin{center}     \begin{longtable}[t]{K{.1\linewidth}K{.6\linewidth}C{.15\linewidth}}     \caption*{\textcolor{vubbleu}{Deputy Practice Manager}: Three most and least automatable tasks} \label{app:tab:3tasks_Deputy_Practice_Manager} \\     \small        & \textbf{Task} & \textbf{Automation Score}  \\  \midrule
# Lowest & Staff recruitment & 1.824 \\
#  & Manage finances for the practice including paying bills & 1.833 \\
#  & Use accounting system, online or desktop software, for finances & 2.108 \\
# \cdashline{2-3}
# Highest & Use texting service or patient management service to contact patients for different clinics and to send reminders. & 3.604 \\
#  &  Reconcile information with a phonecall & 3.362 \\
#  &  Answer phone & 3.362 \\
# \bottomrule     \end{longtable}     \end{center}
#
#  %% AVERAGE FEATURE DIFFERENCES:
# \begin{table}[h!]     \caption*{\textcolor{vubbleu}{Deputy Practice Manager}: Largest feature differences relative to the population}     \centering \small     \begin{tabular}{@{}lc@{}}     \textbf{O*NET Feature} & \textbf{Feature Difference}  \\  \midrule
# Clerical (knowledge) & +\SI{16.5}{\percent}  \\
# Economics and Accounting (knowledge) & +\SI{9.1}{\percent}  \\
# Customer and Personal Service (knowledge) & +\SI{8.5}{\percent}  \\
# Communications and Media (knowledge) & +\SI{7.9}{\percent}  \\
# Service Orientation (skill) & +\SI{6.9}{\percent}  \\
# \midrule
# Repairing (skill) & \SI{-24.4}{\percent}  \\
# Reaction Time (ability) & \SI{-24.0}{\percent}  \\
# Multilimb Coordination (ability) & \SI{-23.2}{\percent}  \\
# Equipment Maintenance (skill) & \SI{-22.9}{\percent}  \\
# Mechanical (knowledge) & \SI{-22.5}{\percent}  \\
# \bottomrule     \end{tabular}     \label{tab:tab:feature_diff_Deputy_Practice_Manager}     \end{table}
#
#  %% AVERAGE FEATURE GRADIENTS:
# \begin{table}[h!]     \caption*{\textcolor{vubbleu}{Deputy Practice Manager}: O*NET features with the largest (positive and negative) derivatives.}     \centering \small     \begin{tabular}{@{}lc@{}}     \textbf{O*NET Feature} & \textbf{Feature Gradient}  \\  \midrule
# Programming (skill) & -0.172  \\
# Technology Design (skill) & -0.163  \\
# Installation (skill) & -0.144  \\
# Fine Arts (knowledge) & -0.142  \\
# Science (skill) & -0.117  \\
# \midrule
# Clerical (knowledge) & +0.169  \\
# Telecommunications (knowledge) & +0.164  \\
# Wrist-Finger Speed (ability) & +0.153  \\
# Number Facility (ability) & +0.123  \\
# Building and Construction (knowledge) & +0.100  \\
# \bottomrule     \end{tabular}     \label{tab:tab:feature_grad_Deputy_Practice_Manager}     \end{table}
# \newpage
#
#  %% General_Practitioner (19, 7)
# \subsubsection*{General Practitioner}
# \begin{center}     \begin{longtable}[t]{K{.1\linewidth}K{.6\linewidth}C{.15\linewidth}}     \caption*{\textcolor{vubbleu}{General Practitioner}: Three most and least automatable tasks} \label{app:tab:3tasks_General_Practitioner} \\     \small        & \textbf{Task} & \textbf{Automation Score}  \\  \midrule
# Lowest & Print out lab test labels in ICE & 1.760 \\
#  & Write notes on paper & 2.235 \\
#  & Fill out/sign third party reports & 2.590 \\
# \cdashline{2-3}
# Highest & Reconcile information with a phonecall & 3.362 \\
#  &  Review letters & 3.215 \\
#  &  Respond to tasks in electronic medical record & 3.091 \\
# \bottomrule     \end{longtable}     \end{center}
#
#  %% AVERAGE FEATURE DIFFERENCES:
# \begin{table}[h!]     \caption*{\textcolor{vubbleu}{General Practitioner}: Largest feature differences relative to the population}     \centering \small     \begin{tabular}{@{}lc@{}}     \textbf{O*NET Feature} & \textbf{Feature Difference}  \\  \midrule
# Clerical (knowledge) & +\SI{19.1}{\percent}  \\
# Medicine and Dentistry (knowledge) & +\SI{16.4}{\percent}  \\
# Customer and Personal Service (knowledge) & +\SI{12.7}{\percent}  \\
# Therapy and Counseling (knowledge) & +\SI{11.6}{\percent}  \\
# English Language (knowledge) & +\SI{8.5}{\percent}  \\
# \midrule
# Repairing (skill) & \SI{-26.6}{\percent}  \\
# Equipment Maintenance (skill) & \SI{-26.0}{\percent}  \\
# Reaction Time (ability) & \SI{-25.1}{\percent}  \\
# Engineering and Technology (knowledge) & \SI{-24.6}{\percent}  \\
# Rate Control (ability) & \SI{-24.3}{\percent}  \\
# \bottomrule     \end{tabular}     \label{tab:tab:feature_diff_General_Practitioner}     \end{table}
#
#  %% AVERAGE FEATURE GRADIENTS:
# \begin{table}[h!]     \caption*{\textcolor{vubbleu}{General Practitioner}: O*NET features with the largest (positive and negative) derivatives.}     \centering \small     \begin{tabular}{@{}lc@{}}     \textbf{O*NET Feature} & \textbf{Feature Gradient}  \\  \midrule
# Programming (skill) & -0.170  \\
# Technology Design (skill) & -0.156  \\
# Fine Arts (knowledge) & -0.149  \\
# Installation (skill) & -0.136  \\
# Food Production (knowledge) & -0.126  \\
# \midrule
# Clerical (knowledge) & +0.168  \\
# Telecommunications (knowledge) & +0.156  \\
# Wrist-Finger Speed (ability) & +0.151  \\
# Number Facility (ability) & +0.122  \\
# Mathematics\_x (skill) & +0.097  \\
# \bottomrule     \end{tabular}     \label{tab:tab:feature_grad_General_Practitioner}     \end{table}
# \newpage
#
#  %% Healthcare_Assistant (11, 7)
# \subsubsection*{Healthcare Assistant}
# \begin{center}     \begin{longtable}[t]{K{.1\linewidth}K{.6\linewidth}C{.15\linewidth}}     \caption*{\textcolor{vubbleu}{Healthcare Assistant}: Three most and least automatable tasks} \label{app:tab:3tasks_Healthcare_Assistant} \\     \small        & \textbf{Task} & \textbf{Automation Score}  \\  \midrule
# Lowest & Label blood vials & 1.760 \\
#  & Print out lab test labels in ICE & 1.760 \\
#  & Write notes on paper & 2.235 \\
# \cdashline{2-3}
# Highest & Reconcile information with a phonecall & 3.362 \\
#  &  Answer phone & 3.362 \\
#  &  Send messages in electronic health record to communicate to other staff & 3.304 \\
# \bottomrule     \end{longtable}     \end{center}
#
#  %% AVERAGE FEATURE DIFFERENCES:
# \begin{table}[h!]     \caption*{\textcolor{vubbleu}{Healthcare Assistant}: Largest feature differences relative to the population}     \centering \small     \begin{tabular}{@{}lc@{}}     \textbf{O*NET Feature} & \textbf{Feature Difference}  \\  \midrule
# Installation (skill) & +\SI{33.0}{\percent}  \\
# Clerical (knowledge) & +\SI{12.3}{\percent}  \\
# Customer and Personal Service (knowledge) & +\SI{9.3}{\percent}  \\
# Foreign Language (knowledge) & +\SI{5.6}{\percent}  \\
# Telecommunications (knowledge) & +\SI{5.4}{\percent}  \\
# \midrule
# Science (skill) & \SI{-22.8}{\percent}  \\
# Chemistry (knowledge) & \SI{-19.3}{\percent}  \\
# Food Production (knowledge) & \SI{-17.6}{\percent}  \\
# Biology (knowledge) & \SI{-15.7}{\percent}  \\
# Management of Financial Resources (skill) & \SI{-12.8}{\percent}  \\
# \bottomrule     \end{tabular}     \label{tab:tab:feature_diff_Healthcare_Assistant}     \end{table}
#
#  %% AVERAGE FEATURE GRADIENTS:
# \begin{table}[h!]     \caption*{\textcolor{vubbleu}{Healthcare Assistant}: O*NET features with the largest (positive and negative) derivatives.}     \centering \small     \begin{tabular}{@{}lc@{}}     \textbf{O*NET Feature} & \textbf{Feature Gradient}  \\  \midrule
# Programming (skill) & -0.149  \\
# Installation (skill) & -0.142  \\
# Technology Design (skill) & -0.141  \\
# Fine Arts (knowledge) & -0.129  \\
# Dynamic Flexibility (ability) & -0.111  \\
# \midrule
# Telecommunications (knowledge) & +0.163  \\
# Clerical (knowledge) & +0.155  \\
# Wrist-Finger Speed (ability) & +0.141  \\
# Number Facility (ability) & +0.110  \\
# Mathematics\_x (skill) & +0.088  \\
# \bottomrule     \end{tabular}     \label{tab:tab:feature_grad_Healthcare_Assistant}     \end{table}
# \newpage
#
#  %% Nurse_Practitioner (16, 7)
# \subsubsection*{Nurse Practitioner}
# \begin{center}     \begin{longtable}[t]{K{.1\linewidth}K{.6\linewidth}C{.15\linewidth}}     \caption*{\textcolor{vubbleu}{Nurse Practitioner}: Three most and least automatable tasks} \label{app:tab:3tasks_Nurse_Practitioner} \\     \small        & \textbf{Task} & \textbf{Automation Score}  \\  \midrule
# Lowest & Print out lab test labels in ICE & 1.760 \\
#  & Write notes on paper & 2.235 \\
#  & Giving advice to colleagues/discuss medicine and other professional topics & 2.687 \\
# \cdashline{2-3}
# Highest & Reconcile information with a phonecall & 3.362 \\
#  &  Answer phone & 3.362 \\
#  &  Send messages in electronic health record to communicate to other staff & 3.304 \\
# \bottomrule     \end{longtable}     \end{center}
#
#  %% AVERAGE FEATURE DIFFERENCES:
# \begin{table}[h!]     \caption*{\textcolor{vubbleu}{Nurse Practitioner}: Largest feature differences relative to the population}     \centering \small     \begin{tabular}{@{}lc@{}}     \textbf{O*NET Feature} & \textbf{Feature Difference}  \\  \midrule
# Medicine and Dentistry (knowledge) & +\SI{16.2}{\percent}  \\
# Clerical (knowledge) & +\SI{12.7}{\percent}  \\
# Customer and Personal Service (knowledge) & +\SI{10.2}{\percent}  \\
# Therapy and Counseling (knowledge) & +\SI{8.9}{\percent}  \\
# Service Orientation (skill) & +\SI{6.0}{\percent}  \\
# \midrule
# Engineering and Technology (knowledge) & \SI{-20.4}{\percent}  \\
# Design (knowledge) & \SI{-18.9}{\percent}  \\
# Building and Construction (knowledge) & \SI{-17.0}{\percent}  \\
# Mechanical (knowledge) & \SI{-14.7}{\percent}  \\
# Physics (knowledge) & \SI{-14.6}{\percent}  \\
# \bottomrule     \end{tabular}     \label{tab:tab:feature_diff_Nurse_Practitioner}     \end{table}
#
#  %% AVERAGE FEATURE GRADIENTS:
# \begin{table}[h!]     \caption*{\textcolor{vubbleu}{Nurse Practitioner}: O*NET features with the largest (positive and negative) derivatives.}     \centering \small     \begin{tabular}{@{}lc@{}}     \textbf{O*NET Feature} & \textbf{Feature Gradient}  \\  \midrule
# Installation (skill) & -0.164  \\
# Programming (skill) & -0.157  \\
# Technology Design (skill) & -0.147  \\
# Fine Arts (knowledge) & -0.135  \\
# Food Production (knowledge) & -0.123  \\
# \midrule
# Telecommunications (knowledge) & +0.161  \\
# Clerical (knowledge) & +0.161  \\
# Wrist-Finger Speed (ability) & +0.145  \\
# Number Facility (ability) & +0.116  \\
# Mathematics\_x (skill) & +0.092  \\
# \bottomrule     \end{tabular}     \label{tab:tab:feature_grad_Nurse_Practitioner}     \end{table}
# \newpage
#
#  %% Pharmacy_Technician (6, 7)
# \subsubsection*{Pharmacy Technician}
# \begin{center}     \begin{longtable}[t]{K{.1\linewidth}K{.6\linewidth}C{.15\linewidth}}     \caption*{\textcolor{vubbleu}{Pharmacy Technician}: Three most and least automatable tasks} \label{app:tab:3tasks_Pharmacy_Technician} \\     \small        & \textbf{Task} & \textbf{Automation Score}  \\  \midrule
# Lowest & Write notes on paper & 2.235 \\
#  & Perform administrative tasks & 2.743 \\
#  & Cleaning up information in the patients electronic health record if there are any problems or incorrect or incomplete information & 2.783 \\
# \cdashline{2-3}
# Highest & Answer phone & 3.362 \\
#  &  Control prescription refills or authorizations. & 3.351 \\
#  &  Send messages in electronic health record to communicate to other staff & 3.304 \\
# \bottomrule     \end{longtable}     \end{center}
#
#  %% AVERAGE FEATURE DIFFERENCES:
# \begin{table}[h!]     \caption*{\textcolor{vubbleu}{Pharmacy Technician}: Largest feature differences relative to the population}     \centering \small     \begin{tabular}{@{}lc@{}}     \textbf{O*NET Feature} & \textbf{Feature Difference}  \\  \midrule
# Medicine and Dentistry (knowledge) & +\SI{21.5}{\percent}  \\
# Clerical (knowledge) & +\SI{11.5}{\percent}  \\
# Communications and Media (knowledge) & +\SI{6.9}{\percent}  \\
# Customer and Personal Service (knowledge) & +\SI{6.3}{\percent}  \\
# Therapy and Counseling (knowledge) & +\SI{5.7}{\percent}  \\
# \midrule
# Building and Construction (knowledge) & \SI{-29.0}{\percent}  \\
# Engineering and Technology (knowledge) & \SI{-25.7}{\percent}  \\
# Design (knowledge) & \SI{-22.6}{\percent}  \\
# Mechanical (knowledge) & \SI{-22.0}{\percent}  \\
# Peripheral Vision (ability) & \SI{-18.8}{\percent}  \\
# \bottomrule     \end{tabular}     \label{tab:tab:feature_diff_Pharmacy_Technician}     \end{table}
#
#  %% AVERAGE FEATURE GRADIENTS:
# \begin{table}[h!]     \caption*{\textcolor{vubbleu}{Pharmacy Technician}: O*NET features with the largest (positive and negative) derivatives.}     \centering \small     \begin{tabular}{@{}lc@{}}     \textbf{O*NET Feature} & \textbf{Feature Gradient}  \\  \midrule
# Installation (skill) & -0.176  \\
# Programming (skill) & -0.170  \\
# Technology Design (skill) & -0.155  \\
# Fine Arts (knowledge) & -0.141  \\
# Food Production (knowledge) & -0.137  \\
# \midrule
# Clerical (knowledge) & +0.168  \\
# Telecommunications (knowledge) & +0.164  \\
# Wrist-Finger Speed (ability) & +0.149  \\
# Number Facility (ability) & +0.121  \\
# Mathematics\_x (skill) & +0.095  \\
# \bottomrule     \end{tabular}     \label{tab:tab:feature_grad_Pharmacy_Technician}     \end{table}
# \newpage
#
#  %% Phlebotomist (1, 7)
# \subsubsection*{Phlebotomist}
# \begin{center}     \begin{longtable}[t]{K{.1\linewidth}K{.6\linewidth}C{.15\linewidth}}     \caption*{\textcolor{vubbleu}{Phlebotomist}: Three most and least automatable tasks} \label{app:tab:3tasks_Phlebotomist} \\     \small        & \textbf{Task} & \textbf{Automation Score}  \\  \midrule
# Lowest & Label blood vials & 1.760 \\
# \cdashline{2-3}
# Highest & Label blood vials & 1.760 \\
# \bottomrule     \end{longtable}     \end{center}
#
#  %% AVERAGE FEATURE DIFFERENCES:
# \begin{table}[h!]     \caption*{\textcolor{vubbleu}{Phlebotomist}: Largest feature differences relative to the population}     \centering \small     \begin{tabular}{@{}lc@{}}     \textbf{O*NET Feature} & \textbf{Feature Difference}  \\  \midrule
# Installation (skill) & +\SI{228.0}{\percent}  \\
# Building and Construction (knowledge) & +\SI{130.5}{\percent}  \\
# Mechanical (knowledge) & +\SI{82.6}{\percent}  \\
# Design (knowledge) & +\SI{72.4}{\percent}  \\
# Repairing (skill) & +\SI{65.8}{\percent}  \\
# \midrule
# Medicine and Dentistry (knowledge) & \SI{-41.6}{\percent}  \\
# Therapy and Counseling (knowledge) & \SI{-40.6}{\percent}  \\
# Biology (knowledge) & \SI{-33.1}{\percent}  \\
# Sociology and Anthropology (knowledge) & \SI{-33.0}{\percent}  \\
# Psychology (knowledge) & \SI{-31.9}{\percent}  \\
# \bottomrule     \end{tabular}     \label{tab:tab:feature_diff_Phlebotomist}     \end{table}
#
#  %% AVERAGE FEATURE GRADIENTS:
# \begin{table}[h!]     \caption*{\textcolor{vubbleu}{Phlebotomist}: O*NET features with the largest (positive and negative) derivatives.}     \centering \small     \begin{tabular}{@{}lc@{}}     \textbf{O*NET Feature} & \textbf{Feature Gradient}  \\  \midrule
# Gross Body Equilibrium (ability) & -0.147  \\
# Speed of Limb Movement (ability) & -0.091  \\
# Medicine and Dentistry (knowledge) & -0.091  \\
# Glare Sensitivity (ability) & -0.089  \\
# Sociology and Anthropology (knowledge) & -0.077  \\
# \midrule
# Telecommunications (knowledge) & +0.149  \\
# Wrist-Finger Speed (ability) & +0.077  \\
# Clerical (knowledge) & +0.075  \\
# Design (knowledge) & +0.071  \\
# Number Facility (ability) & +0.056  \\
# \bottomrule     \end{tabular}     \label{tab:tab:feature_grad_Phlebotomist}     \end{table}
# \newpage
#
#  %% Practice_Manager (37, 7)
# \subsubsection*{Practice Manager}
# \begin{center}     \begin{longtable}[t]{K{.1\linewidth}K{.6\linewidth}C{.15\linewidth}}     \caption*{\textcolor{vubbleu}{Practice Manager}: Three most and least automatable tasks} \label{app:tab:3tasks_Practice_Manager} \\     \small        & \textbf{Task} & \textbf{Automation Score}  \\  \midrule
# Lowest & Staff recruitment & 1.824 \\
#  & Manage finances for the practice including paying bills & 1.833 \\
#  & Having practice staff take online training & 1.908 \\
# \cdashline{2-3}
# Highest & Answer phone & 3.362 \\
#  &  Reconcile information with a phonecall & 3.362 \\
#  &  Work in patient management system for QOF, Recalls, or other patient communication systems & 3.348 \\
# \bottomrule     \end{longtable}     \end{center}
#
#  %% AVERAGE FEATURE DIFFERENCES:
# \begin{table}[h!]     \caption*{\textcolor{vubbleu}{Practice Manager}: Largest feature differences relative to the population}     \centering \small     \begin{tabular}{@{}lc@{}}     \textbf{O*NET Feature} & \textbf{Feature Difference}  \\  \midrule
# Clerical (knowledge) & +\SI{16.2}{\percent}  \\
# Economics and Accounting (knowledge) & +\SI{8.8}{\percent}  \\
# Customer and Personal Service (knowledge) & +\SI{8.6}{\percent}  \\
# Personnel and Human Resources (knowledge) & +\SI{8.4}{\percent}  \\
# Service Orientation (skill) & +\SI{7.1}{\percent}  \\
# \midrule
# Repairing (skill) & \SI{-25.0}{\percent}  \\
# Equipment Maintenance (skill) & \SI{-24.3}{\percent}  \\
# Equipment Selection (skill) & \SI{-24.1}{\percent}  \\
# Multilimb Coordination (ability) & \SI{-23.8}{\percent}  \\
# Mechanical (knowledge) & \SI{-23.3}{\percent}  \\
# \bottomrule     \end{tabular}     \label{tab:tab:feature_diff_Practice_Manager}     \end{table}
#
#  %% AVERAGE FEATURE GRADIENTS:
# \begin{table}[h!]     \caption*{\textcolor{vubbleu}{Practice Manager}: O*NET features with the largest (positive and negative) derivatives.}     \centering \small     \begin{tabular}{@{}lc@{}}     \textbf{O*NET Feature} & \textbf{Feature Gradient}  \\  \midrule
# Programming (skill) & -0.171  \\
# Technology Design (skill) & -0.162  \\
# Installation (skill) & -0.146  \\
# Fine Arts (knowledge) & -0.145  \\
# Science (skill) & -0.115  \\
# \midrule
# Clerical (knowledge) & +0.169  \\
# Telecommunications (knowledge) & +0.162  \\
# Wrist-Finger Speed (ability) & +0.151  \\
# Number Facility (ability) & +0.123  \\
# Mathematics\_x (skill) & +0.099  \\
# \bottomrule     \end{tabular}     \label{tab:tab:feature_grad_Practice_Manager}     \end{table}
# \newpage
#
#  %% Practice_Nurse (17, 7)
# \subsubsection*{Practice Nurse}
# \begin{center}     \begin{longtable}[t]{K{.1\linewidth}K{.6\linewidth}C{.15\linewidth}}     \caption*{\textcolor{vubbleu}{Practice Nurse}: Three most and least automatable tasks} \label{app:tab:3tasks_Practice_Nurse} \\     \small        & \textbf{Task} & \textbf{Automation Score}  \\  \midrule
# Lowest & Print out lab test labels in ICE & 1.760 \\
#  & Label blood vials & 1.760 \\
#  & Write notes on paper & 2.235 \\
# \cdashline{2-3}
# Highest & Answer phone & 3.362 \\
#  &  Reconcile information with a phonecall & 3.362 \\
#  &  Send messages in electronic health record to communicate to other staff & 3.304 \\
# \bottomrule     \end{longtable}     \end{center}
#
#  %% AVERAGE FEATURE DIFFERENCES:
# \begin{table}[h!]     \caption*{\textcolor{vubbleu}{Practice Nurse}: Largest feature differences relative to the population}     \centering \small     \begin{tabular}{@{}lc@{}}     \textbf{O*NET Feature} & \textbf{Feature Difference}  \\  \midrule
# Installation (skill) & +\SI{16.1}{\percent}  \\
# Clerical (knowledge) & +\SI{13.8}{\percent}  \\
# Customer and Personal Service (knowledge) & +\SI{10.9}{\percent}  \\
# Medicine and Dentistry (knowledge) & +\SI{6.0}{\percent}  \\
# Service Orientation (skill) & +\SI{5.2}{\percent}  \\
# \midrule
# Science (skill) & \SI{-18.7}{\percent}  \\
# Engineering and Technology (knowledge) & \SI{-17.2}{\percent}  \\
# Chemistry (knowledge) & \SI{-17.0}{\percent}  \\
# Physics (knowledge) & \SI{-14.8}{\percent}  \\
# Food Production (knowledge) & \SI{-14.6}{\percent}  \\
# \bottomrule     \end{tabular}     \label{tab:tab:feature_diff_Practice_Nurse}     \end{table}
#
#  %% AVERAGE FEATURE GRADIENTS:
# \begin{table}[h!]     \caption*{\textcolor{vubbleu}{Practice Nurse}: O*NET features with the largest (positive and negative) derivatives.}     \centering \small     \begin{tabular}{@{}lc@{}}     \textbf{O*NET Feature} & \textbf{Feature Gradient}  \\  \midrule
# Programming (skill) & -0.155  \\
# Installation (skill) & -0.149  \\
# Technology Design (skill) & -0.146  \\
# Fine Arts (knowledge) & -0.134  \\
# Food Production (knowledge) & -0.116  \\
# \midrule
# Telecommunications (knowledge) & +0.161  \\
# Clerical (knowledge) & +0.159  \\
# Wrist-Finger Speed (ability) & +0.144  \\
# Number Facility (ability) & +0.115  \\
# Mathematics\_x (skill) & +0.092  \\
# \bottomrule     \end{tabular}     \label{tab:tab:feature_grad_Practice_Nurse}     \end{table}
# \newpage
#
#  %% Practice_Pharmacist (12, 7)
# \subsubsection*{Practice Pharmacist}
# \begin{center}     \begin{longtable}[t]{K{.1\linewidth}K{.6\linewidth}C{.15\linewidth}}     \caption*{\textcolor{vubbleu}{Practice Pharmacist}: Three most and least automatable tasks} \label{app:tab:3tasks_Practice_Pharmacist} \\     \small        & \textbf{Task} & \textbf{Automation Score}  \\  \midrule
# Lowest & Write notes on paper & 2.235 \\
#  & Cleaning up information in the patients electronic health record if there are any problems or incorrect or incomplete information & 2.783 \\
#  & Look into drug shortages or other issues with drugs & 2.880 \\
# \cdashline{2-3}
# Highest & Perscription queries & 3.375 \\
#  &  Perform Medication reviews & 3.375 \\
#  &  Answer phone & 3.362 \\
# \bottomrule     \end{longtable}     \end{center}
#
#  %% AVERAGE FEATURE DIFFERENCES:
# \begin{table}[h!]     \caption*{\textcolor{vubbleu}{Practice Pharmacist}: Largest feature differences relative to the population}     \centering \small     \begin{tabular}{@{}lc@{}}     \textbf{O*NET Feature} & \textbf{Feature Difference}  \\  \midrule
# Medicine and Dentistry (knowledge) & +\SI{18.4}{\percent}  \\
# Clerical (knowledge) & +\SI{14.9}{\percent}  \\
# Customer and Personal Service (knowledge) & +\SI{11.1}{\percent}  \\
# Sales and Marketing (knowledge) & +\SI{6.3}{\percent}  \\
# Service Orientation (skill) & +\SI{4.8}{\percent}  \\
# \midrule
# Engineering and Technology (knowledge) & \SI{-25.8}{\percent}  \\
# Design (knowledge) & \SI{-25.6}{\percent}  \\
# Building and Construction (knowledge) & \SI{-25.5}{\percent}  \\
# Spatial Orientation (ability) & \SI{-19.6}{\percent}  \\
# Glare Sensitivity (ability) & \SI{-19.5}{\percent}  \\
# \bottomrule     \end{tabular}     \label{tab:tab:feature_diff_Practice_Pharmacist}     \end{table}
#
#  %% AVERAGE FEATURE GRADIENTS:
# \begin{table}[h!]     \caption*{\textcolor{vubbleu}{Practice Pharmacist}: O*NET features with the largest (positive and negative) derivatives.}     \centering \small     \begin{tabular}{@{}lc@{}}     \textbf{O*NET Feature} & \textbf{Feature Gradient}  \\  \midrule
# Installation (skill) & -0.171  \\
# Programming (skill) & -0.166  \\
# Technology Design (skill) & -0.157  \\
# Fine Arts (knowledge) & -0.136  \\
# Food Production (knowledge) & -0.127  \\
# \midrule
# Clerical (knowledge) & +0.166  \\
# Telecommunications (knowledge) & +0.163  \\
# Wrist-Finger Speed (ability) & +0.149  \\
# Number Facility (ability) & +0.122  \\
# Mathematics\_x (skill) & +0.096  \\
# \bottomrule     \end{tabular}     \label{tab:tab:feature_grad_Practice_Pharmacist}     \end{table}
# \newpage
#
#  %% Prescription_Clerk (4, 7)
# \subsubsection*{Prescription Clerk}
# \begin{center}     \begin{longtable}[t]{K{.1\linewidth}K{.6\linewidth}C{.15\linewidth}}     \caption*{\textcolor{vubbleu}{Prescription Clerk}: Three most and least automatable tasks} \label{app:tab:3tasks_Prescription_Clerk} \\     \small        & \textbf{Task} & \textbf{Automation Score}  \\  \midrule
# Lowest & Process out of hours reports and create tasks to assign to GPs & 2.783 \\
#  & Answer queries from patients or from GPs about perscriptions & 2.964 \\
#  & Process perscription renewals & 3.067 \\
# \cdashline{2-3}
# Highest & Check prescriptions for medication renewals and send to GP & 3.351 \\
#  &  Process perscription renewals & 3.067 \\
#  &  Answer queries from patients or from GPs about perscriptions & 2.964 \\
# \bottomrule     \end{longtable}     \end{center}
#
#  %% AVERAGE FEATURE DIFFERENCES:
# \begin{table}[h!]     \caption*{\textcolor{vubbleu}{Prescription Clerk}: Largest feature differences relative to the population}     \centering \small     \begin{tabular}{@{}lc@{}}     \textbf{O*NET Feature} & \textbf{Feature Difference}  \\  \midrule
# Medicine and Dentistry (knowledge) & +\SI{64.6}{\percent}  \\
# Therapy and Counseling (knowledge) & +\SI{27.9}{\percent}  \\
# Biology (knowledge) & +\SI{26.4}{\percent}  \\
# Customer and Personal Service (knowledge) & +\SI{20.5}{\percent}  \\
# Clerical (knowledge) & +\SI{19.7}{\percent}  \\
# \midrule
# Design (knowledge) & \SI{-36.2}{\percent}  \\
# Engineering and Technology (knowledge) & \SI{-33.2}{\percent}  \\
# Building and Construction (knowledge) & \SI{-32.7}{\percent}  \\
# Mechanical (knowledge) & \SI{-30.7}{\percent}  \\
# Repairing (skill) & \SI{-29.9}{\percent}  \\
# \bottomrule     \end{tabular}     \label{tab:tab:feature_diff_Prescription_Clerk}     \end{table}
#
#  %% AVERAGE FEATURE GRADIENTS:
# \begin{table}[h!]     \caption*{\textcolor{vubbleu}{Prescription Clerk}: O*NET features with the largest (positive and negative) derivatives.}     \centering \small     \begin{tabular}{@{}lc@{}}     \textbf{O*NET Feature} & \textbf{Feature Gradient}  \\  \midrule
# Programming (skill) & -0.176  \\
# Installation (skill) & -0.161  \\
# Technology Design (skill) & -0.158  \\
# Food Production (knowledge) & -0.152  \\
# Fine Arts (knowledge) & -0.150  \\
# \midrule
# Clerical (knowledge) & +0.175  \\
# Telecommunications (knowledge) & +0.152  \\
# Wrist-Finger Speed (ability) & +0.149  \\
# Number Facility (ability) & +0.132  \\
# Mathematics\_x (skill) & +0.104  \\
# \bottomrule     \end{tabular}     \label{tab:tab:feature_grad_Prescription_Clerk}     \end{table}
# \newpage
#
#  %% Receptionist (38, 7)
# \subsubsection*{Receptionist}
# \begin{center}     \begin{longtable}[t]{K{.1\linewidth}K{.6\linewidth}C{.15\linewidth}}     \caption*{\textcolor{vubbleu}{Receptionist}: Three most and least automatable tasks} \label{app:tab:3tasks_Receptionist} \\     \small        & \textbf{Task} & \textbf{Automation Score}  \\  \midrule
# Lowest & Manage petty cash & 2.070 \\
#  & Write notes on paper & 2.235 \\
#  & Maintain documentation for 2 week waits & 2.399 \\
# \cdashline{2-3}
# Highest & Check and sort mail. & 3.737 \\
#  &  Print letters & 3.609 \\
#  &  Use texting service or patient management service to contact patients for different clinics and to send reminders. & 3.604 \\
# \bottomrule     \end{longtable}     \end{center}
#
#  %% AVERAGE FEATURE DIFFERENCES:
# \begin{table}[h!]     \caption*{\textcolor{vubbleu}{Receptionist}: Largest feature differences relative to the population}     \centering \small     \begin{tabular}{@{}lc@{}}     \textbf{O*NET Feature} & \textbf{Feature Difference}  \\  \midrule
# Clerical (knowledge) & +\SI{23.3}{\percent}  \\
# Medicine and Dentistry (knowledge) & +\SI{17.0}{\percent}  \\
# Customer and Personal Service (knowledge) & +\SI{11.2}{\percent}  \\
# English Language (knowledge) & +\SI{7.2}{\percent}  \\
# Service Orientation (skill) & +\SI{7.0}{\percent}  \\
# \midrule
# Mechanical (knowledge) & \SI{-31.1}{\percent}  \\
# Building and Construction (knowledge) & \SI{-31.0}{\percent}  \\
# Repairing (skill) & \SI{-28.6}{\percent}  \\
# Engineering and Technology (knowledge) & \SI{-28.4}{\percent}  \\
# Design (knowledge) & \SI{-27.6}{\percent}  \\
# \bottomrule     \end{tabular}     \label{tab:tab:feature_diff_Receptionist}     \end{table}
#
#  %% AVERAGE FEATURE GRADIENTS:
# \begin{table}[h!]     \caption*{\textcolor{vubbleu}{Receptionist}: O*NET features with the largest (positive and negative) derivatives.}     \centering \small     \begin{tabular}{@{}lc@{}}     \textbf{O*NET Feature} & \textbf{Feature Gradient}  \\  \midrule
# Programming (skill) & -0.178  \\
# Technology Design (skill) & -0.163  \\
# Fine Arts (knowledge) & -0.159  \\
# Installation (skill) & -0.145  \\
# Food Production (knowledge) & -0.134  \\
# \midrule
# Clerical (knowledge) & +0.176  \\
# Telecommunications (knowledge) & +0.160  \\
# Wrist-Finger Speed (ability) & +0.158  \\
# Number Facility (ability) & +0.126  \\
# Building and Construction (knowledge) & +0.103  \\
# \bottomrule     \end{tabular}     \label{tab:tab:feature_grad_Receptionist}     \end{table}
# \newpage
#
#  %% Scanning_Clerk (1, 7)
# \subsubsection*{Scanning Clerk}
# \begin{center}     \begin{longtable}[t]{K{.1\linewidth}K{.6\linewidth}C{.15\linewidth}}     \caption*{\textcolor{vubbleu}{Scanning Clerk}: Three most and least automatable tasks} \label{app:tab:3tasks_Scanning_Clerk} \\     \small        & \textbf{Task} & \textbf{Automation Score}  \\  \midrule
# Lowest & Scan letters and other documents & 3.514 \\
# \cdashline{2-3}
# Highest & Scan letters and other documents & 3.514 \\
# \bottomrule     \end{longtable}     \end{center}
#
#  %% AVERAGE FEATURE DIFFERENCES:
# \begin{table}[h!]     \caption*{\textcolor{vubbleu}{Scanning Clerk}: Largest feature differences relative to the population}     \centering \small     \begin{tabular}{@{}lc@{}}     \textbf{O*NET Feature} & \textbf{Feature Difference}  \\  \midrule
# Clerical (knowledge) & +\SI{33.1}{\percent}  \\
# Computers and Electronics (knowledge) & +\SI{21.8}{\percent}  \\
# Programming (skill) & +\SI{20.5}{\percent}  \\
# Fine Arts (knowledge) & +\SI{9.9}{\percent}  \\
# Perceptual Speed (ability) & +\SI{9.4}{\percent}  \\
# \midrule
# Science (skill) & \SI{-41.9}{\percent}  \\
# Chemistry (knowledge) & \SI{-37.2}{\percent}  \\
# Physics (knowledge) & \SI{-33.5}{\percent}  \\
# Building and Construction (knowledge) & \SI{-32.6}{\percent}  \\
# Mechanical (knowledge) & \SI{-31.2}{\percent}  \\
# \bottomrule     \end{tabular}     \label{tab:tab:feature_diff_Scanning_Clerk}     \end{table}
#
#  %% AVERAGE FEATURE GRADIENTS:
# \begin{table}[h!]     \caption*{\textcolor{vubbleu}{Scanning Clerk}: O*NET features with the largest (positive and negative) derivatives.}     \centering \small     \begin{tabular}{@{}lc@{}}     \textbf{O*NET Feature} & \textbf{Feature Gradient}  \\  \midrule
# Programming (skill) & -0.183  \\
# Technology Design (skill) & -0.172  \\
# Fine Arts (knowledge) & -0.156  \\
# Installation (skill) & -0.155  \\
# Science (skill) & -0.131  \\
# \midrule
# Clerical (knowledge) & +0.181  \\
# Telecommunications (knowledge) & +0.175  \\
# Wrist-Finger Speed (ability) & +0.172  \\
# Number Facility (ability) & +0.127  \\
# Building and Construction (knowledge) & +0.115  \\
# \bottomrule     \end{tabular}     \label{tab:tab:feature_grad_Scanning_Clerk}     \end{table}
# \newpage
#
#  %% Secretary (23, 7)
# \subsubsection*{Secretary}
# \begin{center}     \begin{longtable}[t]{K{.1\linewidth}K{.6\linewidth}C{.15\linewidth}}     \caption*{\textcolor{vubbleu}{Secretary}: Three most and least automatable tasks} \label{app:tab:3tasks_Secretary} \\     \small        & \textbf{Task} & \textbf{Automation Score}  \\  \midrule
# Lowest & Write notes on paper & 2.235 \\
#  & Write medical report letters & 2.235 \\
#  & Use software for invoicing & 2.378 \\
# \cdashline{2-3}
# Highest & Print letters & 3.609 \\
#  &  Scan letters and other documents & 3.514 \\
#  &  Organise and manage main practice email account. & 3.387 \\
# \bottomrule     \end{longtable}     \end{center}
#
#  %% AVERAGE FEATURE DIFFERENCES:
# \begin{table}[h!]     \caption*{\textcolor{vubbleu}{Secretary}: Largest feature differences relative to the population}     \centering \small     \begin{tabular}{@{}lc@{}}     \textbf{O*NET Feature} & \textbf{Feature Difference}  \\  \midrule
# Clerical (knowledge) & +\SI{19.7}{\percent}  \\
# Customer and Personal Service (knowledge) & +\SI{8.8}{\percent}  \\
# Communications and Media (knowledge) & +\SI{8.4}{\percent}  \\
# Medicine and Dentistry (knowledge) & +\SI{7.1}{\percent}  \\
# English Language (knowledge) & +\SI{6.7}{\percent}  \\
# \midrule
# Mechanical (knowledge) & \SI{-30.5}{\percent}  \\
# Building and Construction (knowledge) & \SI{-30.2}{\percent}  \\
# Repairing (skill) & \SI{-27.3}{\percent}  \\
# Troubleshooting (skill) & \SI{-26.7}{\percent}  \\
# Engineering and Technology (knowledge) & \SI{-26.7}{\percent}  \\
# \bottomrule     \end{tabular}     \label{tab:tab:feature_diff_Secretary}     \end{table}
#
#  %% AVERAGE FEATURE GRADIENTS:
# \begin{table}[h!]     \caption*{\textcolor{vubbleu}{Secretary}: O*NET features with the largest (positive and negative) derivatives.}     \centering \small     \begin{tabular}{@{}lc@{}}     \textbf{O*NET Feature} & \textbf{Feature Gradient}  \\  \midrule
# Programming (skill) & -0.179  \\
# Technology Design (skill) & -0.163  \\
# Fine Arts (knowledge) & -0.156  \\
# Installation (skill) & -0.146  \\
# Food Production (knowledge) & -0.136  \\
# \midrule
# Clerical (knowledge) & +0.175  \\
# Telecommunications (knowledge) & +0.163  \\
# Wrist-Finger Speed (ability) & +0.158  \\
# Number Facility (ability) & +0.126  \\
# Building and Construction (knowledge) & +0.104  \\
# \bottomrule     \end{tabular}     \label{tab:tab:feature_grad_Secretary}     \end{table}
# \newpage
#
#  %% Summariser (6, 7)
# \subsubsection*{Summariser}
# \begin{center}     \begin{longtable}[t]{K{.1\linewidth}K{.6\linewidth}C{.15\linewidth}}     \caption*{\textcolor{vubbleu}{Summariser}: Three most and least automatable tasks} \label{app:tab:3tasks_Summariser} \\     \small        & \textbf{Task} & \textbf{Automation Score}  \\  \midrule
# Lowest & Write notes on paper & 2.235 \\
#  & Cleaning up information in the patients electronic health record if there are any problems or incorrect or incomplete information & 2.783 \\
#  & Medical Coding of letters and other documents & 3.220 \\
# \cdashline{2-3}
# Highest & Answer phone & 3.362 \\
#  &  Send messages in electronic health record to communicate to other staff & 3.304 \\
#  &  Register new Patients & 3.235 \\
# \bottomrule     \end{longtable}     \end{center}
#
#  %% AVERAGE FEATURE DIFFERENCES:
# \begin{table}[h!]     \caption*{\textcolor{vubbleu}{Summariser}: Largest feature differences relative to the population}     \centering \small     \begin{tabular}{@{}lc@{}}     \textbf{O*NET Feature} & \textbf{Feature Difference}  \\  \midrule
# Medicine and Dentistry (knowledge) & +\SI{19.0}{\percent}  \\
# Clerical (knowledge) & +\SI{15.6}{\percent}  \\
# Communications and Media (knowledge) & +\SI{10.6}{\percent}  \\
# Telecommunications (knowledge) & +\SI{7.5}{\percent}  \\
# Computers and Electronics (knowledge) & +\SI{7.4}{\percent}  \\
# \midrule
# Building and Construction (knowledge) & \SI{-27.8}{\percent}  \\
# Spatial Orientation (ability) & \SI{-22.0}{\percent}  \\
# Mechanical (knowledge) & \SI{-20.9}{\percent}  \\
# Design (knowledge) & \SI{-18.9}{\percent}  \\
# Engineering and Technology (knowledge) & \SI{-18.7}{\percent}  \\
# \bottomrule     \end{tabular}     \label{tab:tab:feature_diff_Summariser}     \end{table}
#
#  %% AVERAGE FEATURE GRADIENTS:
# \begin{table}[h!]     \caption*{\textcolor{vubbleu}{Summariser}: O*NET features with the largest (positive and negative) derivatives.}     \centering \small     \begin{tabular}{@{}lc@{}}     \textbf{O*NET Feature} & \textbf{Feature Gradient}  \\  \midrule
# Programming (skill) & -0.172  \\
# Installation (skill) & -0.162  \\
# Technology Design (skill) & -0.157  \\
# Fine Arts (knowledge) & -0.137  \\
# Dynamic Flexibility (ability) & -0.114  \\
# \midrule
# Telecommunications (knowledge) & +0.167  \\
# Clerical (knowledge) & +0.166  \\
# Wrist-Finger Speed (ability) & +0.153  \\
# Number Facility (ability) & +0.118  \\
# Mathematics\_x (skill) & +0.093  \\
# \bottomrule     \end{tabular}     \label{tab:tab:feature_grad_Summariser}     \end{table}
# \newpage

# %% [markdown]
# ## Global Gradients:

# %%
def print_long_top(col_name, cap):
     print("\\begin{center} \
     \\begin{longtable}{@{}lc@{}} \
    \\caption{%s} \
    \\label{app:onet_variable} \\\\  \
    \\small \
    \\textbf{O*NET Feature} & \\textbf{%s}  \\\\  \\midrule" % (cap, col_name))

def print_long_bot(label):
    print("\\bottomrule \
    \\end{longtable} \
    \\label{tab:%s} \
    \\end{center}" % label)
    return

# %%
dwa_all_grads = []
for index, row in task_dataset.iterrows():
    dwas = [i.strip() for i in row['DWA ID'].split(";")]
    weights = [i.strip() for i in row['Task Weight'].split(";")]
    grad_subset = dwa_grads[dwa_grads["DWA ID"].isin(dwas)][cols].values  # FYI: this is not ordered the same as "dwas" 
    dwa_grads_per_set.append(grad_subset.mean(axis=0))
    
dwa_grads = np.vstack(dwa_grads_per_set).mean(axis=0)

# %%
pos_features_presented = int(np.ceil(dwa_grads).sum())
neg_features_presented = int(120 - np.ceil(dwa_grads).sum())

# # These are the characteristics of those tasks (in the sub-set)
neg_grads = [(col, grad) for col, grad in sorted(zip(average_grads, cols))][:neg_features_presented]
poss_grads = [(col, grad) for col, grad in sorted(zip(average_grads, cols), reverse=True)][:pos_features_presented]

risk = occu = "Global"
print("%% taken from Healthcare_DWA_Gradients.ipynb,\n")

print("\n %% GLOBAL AVERAGE FEATURE GRADIENTS:")    
caption = "\\textcolor{vubbleu}{%s}: All O*NET feature derivatives." % occu
print_long_top("Feature Gradient", caption)
for (i, j) in poss_grads:
    
    print(j.replace("_", "\_") , "(%s) & +%0.3f  \\\\ " % (characteristic_dict[j], i))

print("\\midrule")
for (i, j) in neg_grads:
    print(j.replace("_", "\_") , "(%s) & %0.3f  \\\\ " % (characteristic_dict[j], i)) 
label = "feature_grad_%s" % risk    
print_long_bot(label)
# Out:
# %% taken from Healthcare_DWA_Gradients.ipynb,
#
#
#  %% GLOBAL AVERAGE FEATURE GRADIENTS:
# \begin{center}      \begin{longtable}{@{}lc@{}}     \caption{\textcolor{vubbleu}{Global}: All O*NET feature derivatives.}     \label{app:onet_variable} \\      \small     \textbf{O*NET Feature} & \textbf{Feature Gradient}  \\  \midrule
# Telecommunications (knowledge) & +0.167  \\
# Clerical (knowledge) & +0.166  \\
# Wrist-Finger Speed (ability) & +0.153  \\
# Number Facility (ability) & +0.118  \\
# Mathematics\_x (skill) & +0.093  \\
# Depth Perception (ability) & +0.092  \\
# Building and Construction (knowledge) & +0.090  \\
# Mathematical Reasoning (ability) & +0.088  \\
# Economics and Accounting (knowledge) & +0.085  \\
# Control Precision (ability) & +0.082  \\
# Response Orientation (ability) & +0.081  \\
# Arm-Hand Steadiness (ability) & +0.077  \\
# Sales and Marketing (knowledge) & +0.076  \\
# Equipment Selection (skill) & +0.072  \\
# Finger Dexterity (ability) & +0.067  \\
# Perceptual Speed (ability) & +0.066  \\
# Static Strength (ability) & +0.059  \\
# Visual Color Discrimination (ability) & +0.058  \\
# Far Vision (ability) & +0.046  \\
# Spatial Orientation (ability) & +0.046  \\
# Multilimb Coordination (ability) & +0.045  \\
# Manual Dexterity (ability) & +0.042  \\
# Extent Flexibility (ability) & +0.041  \\
# Production and Processing (knowledge) & +0.038  \\
# Flexibility of Closure (ability) & +0.035  \\
# Night Vision (ability) & +0.034  \\
# Transportation (knowledge) & +0.025  \\
# Near Vision (ability) & +0.023  \\
# Dynamic Strength (ability) & +0.023  \\
# Writing (skill) & +0.023  \\
# Speed of Closure (ability) & +0.022  \\
# Computers and Electronics (knowledge) & +0.022  \\
# Operation Monitoring (skill) & +0.017  \\
# Visualization (ability) & +0.016  \\
# Medicine and Dentistry (knowledge) & +0.014  \\
# Equipment Maintenance (skill) & +0.013  \\
# Education and Training (knowledge) & +0.012  \\
# Category Flexibility (ability) & +0.012  \\
# Biology (knowledge) & +0.012  \\
# Written Comprehension (ability) & +0.011  \\
# Sound Localization (ability) & +0.011  \\
# Inductive Reasoning (ability) & +0.011  \\
# Selective Attention (ability) & +0.009  \\
# Mathematics\_y (knowledge) & +0.009  \\
# Written Expression (ability) & +0.008  \\
# Peripheral Vision (ability) & +0.007  \\
# Reading Comprehension (skill) & +0.006  \\
# Operation and Control (skill) & +0.006  \\
# Rate Control (ability) & +0.003  \\
# Administration and Management (knowledge) & +0.002  \\
# Information Ordering (ability) & +0.002  \\
# \midrule
# Programming (skill) & -0.172  \\
# Installation (skill) & -0.162  \\
# Technology Design (skill) & -0.157  \\
# Fine Arts (knowledge) & -0.137  \\
# Dynamic Flexibility (ability) & -0.114  \\
# Psychology (knowledge) & -0.113  \\
# History and Archeology (knowledge) & -0.109  \\
# Science (skill) & -0.107  \\
# Sociology and Anthropology (knowledge) & -0.105  \\
# Food Production (knowledge) & -0.105  \\
# Personnel and Human Resources (knowledge) & -0.102  \\
# Speed of Limb Movement (ability) & -0.100  \\
# Management of Personnel Resources (skill) & -0.082  \\
# Gross Body Equilibrium (ability) & -0.080  \\
# Learning Strategies (skill) & -0.071  \\
# Negotiation (skill) & -0.069  \\
# Troubleshooting (skill) & -0.068  \\
# Coordination (skill) & -0.068  \\
# Glare Sensitivity (ability) & -0.067  \\
# Law and Government (knowledge) & -0.067  \\
# Chemistry (knowledge) & -0.065  \\
# Explosive Strength (ability) & -0.064  \\
# Social Perceptiveness (skill) & -0.063  \\
# Gross Body Coordination (ability) & -0.062  \\
# Originality (ability) & -0.058  \\
# Persuasion (skill) & -0.057  \\
# Management of Financial Resources (skill) & -0.057  \\
# Public Safety and Security (knowledge) & -0.047  \\
# English Language (knowledge) & -0.047  \\
# Instructing (skill) & -0.046  \\
# Operations Analysis (skill) & -0.044  \\
# Communications and Media (knowledge) & -0.042  \\
# Management of Material Resources (skill) & -0.041  \\
# Engineering and Technology (knowledge) & -0.041  \\
# Time Management (skill) & -0.038  \\
# Fluency of Ideas (ability) & -0.038  \\
# Physics (knowledge) & -0.037  \\
# Active Learning (skill) & -0.036  \\
# Service Orientation (skill) & -0.030  \\
# Mechanical (knowledge) & -0.030  \\
# Time Sharing (ability) & -0.029  \\
# Oral Expression (ability) & -0.029  \\
# Geography (knowledge) & -0.027  \\
# Monitoring (skill) & -0.025  \\
# Reaction Time (ability) & -0.023  \\
# Customer and Personal Service (knowledge) & -0.023  \\
# Speaking (skill) & -0.020  \\
# Active Listening (skill) & -0.020  \\
# Hearing Sensitivity (ability) & -0.019  \\
# Stamina (ability) & -0.018  \\
# Foreign Language (knowledge) & -0.018  \\
# Complex Problem Solving (skill) & -0.016  \\
# Speech Clarity (ability) & -0.016  \\
# Philosophy and Theology (knowledge) & -0.015  \\
# Speech Recognition (ability) & -0.014  \\
# Trunk Strength (ability) & -0.014  \\
# Problem Sensitivity (ability) & -0.013  \\
# Oral Comprehension (ability) & -0.012  \\
# Judgment and Decision Making (skill) & -0.012  \\
# Critical Thinking (skill) & -0.012  \\
# Auditory Attention (ability) & -0.011  \\
# Memorization (ability) & -0.010  \\
# Repairing (skill) & -0.008  \\
# Quality Control Analysis (skill) & -0.006  \\
# Deductive Reasoning (ability) & -0.005  \\
# Therapy and Counseling (knowledge) & -0.003  \\
# Systems Evaluation (skill) & -0.002  \\
# Systems Analysis (skill) & 0.000  \\
# Design (knowledge) & 0.001  \\
# \bottomrule     \end{longtable}     \label{tab:feature_grad_Global}     \end{center}
